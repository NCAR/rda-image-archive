# %%
# %run rdai

# %%
get_fixed_seq()

# %%
get_normalized_catalog("examples/philip_20190703_example_tree")
# Out:
# RDAI: Tag EXIF:ImageUniqueID=90caab24070011eaa285985aebdcd794 already exists in file examples/philip_20190703_example_tree/IDWR/1892-07-01_1892-12-31/23464096.png.
# RDAI: Wrote tag EXIF:ImageUniqueID=890e75e20c8611eab679985aebdcd794 to file examples/philip_20190703_example_tree/IDWR/1892-07-01_1892-12-31/ncar.jpg_original.
# RDAI: Tag EXIF:ImageUniqueID=dd9b26ca0c8411ea8119985aebdcd794 already exists in file examples/philip_20190703_example_tree/IDWR/1892-07-01_1892-12-31/ncar.jpg.
# {'contents': [{'file_path': 'examples/philip_20190703_example_tree/.coafile',
#    'media_type': 'text/plain',
#    'uuid': None},
#   {'contents': [{'contents': [{'file_path': 'examples/philip_20190703_example_tree/UK_DWR/1903/metadata.csv',
#        'media_type': 'text/plain',
#        'uuid': None}],
#      'document.start_date': '1903',
#      'document.end_date': '1903'},
#     {'file_path': 'examples/philip_20190703_example_tree/UK_DWR/collect_sample.py',
#      'media_type': 'text/x-python',
# ...

# %%
# %ls examples/philip_20190703_example_tree/IDWR/1892-07-01_1892-12-31/
# Out:
# 23464096.png                ncar.jpg_original
# metadata.csv                ncar.jpg_original_original
# ncar.jpg
